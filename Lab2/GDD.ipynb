# %%
import requests
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import time
from sqlalchemy import create_engine, text
import psycopg2

# %%
gdd_csv_path = r'C:\Users\tjjoh\OneDrive\Desktop\GIS 5572\Lab2\gdd.csv'

# %%
url = r'https://www.ncei.noaa.gov/cdo-web/api/v2/stations'
params = {
    'locationid': 'FIPS:27', #Minnesota is 27
    'datasetid': 'GHCND', #Global Historical Climatology Network Daily
    'limit': 1000 #Maximum results per request
}
headers = {'token': 'JgSvDOViKdKyBepyxxCKfJDaMaQghdfB'} #API token

stations = []

# %%
#Get a list of all stations in Minnesota
offset = 0 #Pagination will be necessary to retrieve all the data

while url:
    params['offset'] = offset #set the offset parameter
    try:
        response = requests.get(url, params = params, headers = headers) #make API request
        data = response.json() #transform to json
        
        if 'results' in data:
            stations.extend(data['results'])
            #for i in range(len(data['results'])):
                #stations.extend([data['results'][i]['id']]) #if results exist, add the station ids to the the list
                
            if len(data['results']) < params['limit']: #check if all data has been retrieved
                break
        else:
            break

        offset = offset + params['limit'] #update offset
        
    except:
        print(f'Error retriving data: {response.status_code}')
        break

# %%
url = r'https://www.ncei.noaa.gov/cdo-web/api/v2/data'
params = {
    'datasetid': 'NORMAL_MLY',
    'startdate': '2010-01-01',
    'enddate': '2010-12-01',
    'units': 'standard',
    'limit': 1000
}

# %%
gdd = pd.DataFrame()

for i in range(2189, len(stations)): #the first 2188 give errors
    attempt = 1 #create a counter for how many time to attempt to retrieve data
    max_attempts = 5 #maximum number of attempts
    success = False #default state of whether api request was successful

    while attempt <= max_attempts and not success: #iterate up to 3 times to try and make a successful api call
        try:
            params['stationid'] = stations[i]['id'] #add station id to url parameters
            response = requests.get(url, params = params, headers = headers) #retrieve data
            data = response.json() #convert to json
        
            dd = [stations[i]['id'], stations[i]['latitude'], stations[i]['longitude'], stations[i]['name']] #extract station id, location, and name
            for j in range(len(data['results'])): #iterate through retrieved data
                if data['results'][j]['datatype'] == 'MLY-CLDD-BASE50': #find desired dataset. BMSB become active at around 10C (50F)
                    dd.extend([data['results'][j]['value']]) #add data to station info list

            if len(dd) == 16: #check to see if dd is the proper length
                gdd = pd.concat([gdd, pd.DataFrame([dd])], ignore_index = True) #add to gdd dataframe if the proper data exists
                print(f'{i} Success')
            else:
                print(f'{i} Error: gdd_length = {len(dd)}')

            success = True #api call was succesful

        except:
            if response.status_code == 503: #check if api call was unsuccesful
                attempt += 1
                if attempt <= max_attempts: #if attempts remain, try api request again
                    print(f'{i} Error: 503, Retrying...')
                else: #if no attempts remain, skip point
                    print(f'{i} Error: 503, Failed to retrieve data.')
            elif response.status_code != 200: #check if status is not OK
                print(f'{i} Error: {response.status_code}')
                success = True
            elif len(dd) != 16: #check if dd is the proper length
                print(f'{i} Error: gdd_length = {len(dd)}')
                success = True
            else:
                print(f'{i} Error: unknown')
                success = True

        time.sleep(0.5)
# Out:
# 2189 Success
# 2190 Success
# 2191 Success
# 2192 Success
# 2193 Error: gdd_length = 4
# 2194 Error: gdd_length = 4
# 2195 Error: gdd_length = 4
# 2196 Error: gdd_length = 4
# 2197 Error: gdd_length = 4
# 2198 Error: gdd_length = 4
# 2199 Error: gdd_length = 4
# 2200 Success
# 2201 Success
# 2202 Error: gdd_length = 4
# 2203 Success
# 2204 Success
# 2205 Error: gdd_length = 4
# 2206 Success
# 2207 Success
# 2208 Error: gdd_length = 4
# 2209 Success
# 2210 Error: gdd_length = 4
# 2211 Error: gdd_length = 4
# 2212 Error: gdd_length = 4
# 2213 Error: gdd_length = 4
# 2214 Success
# 2215 Error: gdd_length = 4
# 2216 Success
# 2217 Success
# 2218 Success
# 2219 Error: gdd_length = 4
# 2220 Error: gdd_length = 4
# 2221 Error: gdd_length = 4
# 2222 Error: gdd_length = 4
# 2223 Error: gdd_length = 4
# 2224 Success
# 2225 Error: gdd_length = 4
# 2226 Error: gdd_length = 4
# 2227 Error: gdd_length = 4
# 2228 Error: gdd_length = 4
# 2229 Error: gdd_length = 4
# 2230 Error: gdd_length = 4
# 2231 Success
# 2232 Success
# 2233 Error: gdd_length = 4
# 2234 Error: gdd_length = 4
# 2235 Success
# 2236 Success
# 2237 Success
# 2238 Success
# 2239 Success
# 2240 Success
# 2241 Success
# 2242 Success
# 2243 Success
# 2244 Success
# 2245 Success
# 2246 Error: gdd_length = 4
# 2247 Error: gdd_length = 4
# 2248 Error: gdd_length = 4
# 2249 Error: gdd_length = 4
# 2250 Success
# 2251 Success
# 2252 Error: gdd_length = 4
# 2253 Error: gdd_length = 4
# 2254 Error: gdd_length = 4
# 2255 Success
# 2256 Success
# 2257 Success
# 2258 Error: gdd_length = 4
# 2259 Error: gdd_length = 4
# 2260 Error: gdd_length = 4
# 2261 Error: gdd_length = 4
# 2262 Success
# 2263 Error: gdd_length = 4
# 2264 Error: gdd_length = 4
# 2265 Success
# 2266 Error: gdd_length = 4
# 2267 Success
# 2268 Error: gdd_length = 4
# 2269 Success
# 2270 Error: gdd_length = 4
# 2271 Error: gdd_length = 4
# 2272 Success
# 2273 Error: gdd_length = 4
# 2274 Error: gdd_length = 4
# 2275 Error: gdd_length = 4
# 2276 Success
# 2277 Error: gdd_length = 4
# 2278 Error: gdd_length = 4
# 2279 Error: gdd_length = 4
# 2280 Success
# 2281 Success
# 2282 Error: gdd_length = 4
# 2283 Success
# 2284 Success
# 2285 Error: gdd_length = 4
# 2286 Success
# 2287 Error: gdd_length = 4
# 2288 Error: gdd_length = 4
# 2289 Error: gdd_length = 4
# 2290 Error: gdd_length = 4
# 2291 Success
# 2292 Error: 503, Retrying...
# 2292 Error: gdd_length = 4
# 2293 Error: gdd_length = 4
# 2294 Error: gdd_length = 4
# 2295 Error: gdd_length = 4
# 2296 Error: gdd_length = 4
# 2297 Success
# 2298 Success
# 2299 Success
# 2300 Error: gdd_length = 4
# 2301 Error: gdd_length = 4
# 2302 Success
# 2303 Success
# 2304 Success
# 2305 Error: gdd_length = 4
# 2306 Success
# 2307 Success
# 2308 Error: gdd_length = 4
# 2309 Error: gdd_length = 4
# 2310 Success
# 2311 Error: gdd_length = 4
# 2312 Success
# 2313 Success
# 2314 Error: gdd_length = 4
# 2315 Error: gdd_length = 4
# 2316 Error: gdd_length = 4
# 2317 Success
# 2318 Error: gdd_length = 4
# 2319 Error: gdd_length = 4
# 2320 Error: gdd_length = 4
# 2321 Success
# 2322 Success
# 2323 Error: gdd_length = 4
# 2324 Error: gdd_length = 4
# 2325 Success
# 2326 Error: gdd_length = 4
# 2327 Error: gdd_length = 4
# 2328 Error: gdd_length = 4
# 2329 Success
# 2330 Success
# 2331 Success
# 2332 Error: gdd_length = 4
# 2333 Success
# 2334 Error: gdd_length = 4
# 2335 Success
# 2336 Error: gdd_length = 4
# 2337 Success
# 2338 Success
# 2339 Error: gdd_length = 4
# 2340 Success
# 2341 Error: gdd_length = 4
# 2342 Error: gdd_length = 4
# 2343 Error: gdd_length = 4
# 2344 Success
# 2345 Error: gdd_length = 4
# 2346 Error: 503, Retrying...
# 2346 Error: gdd_length = 4
# 2347 Error: gdd_length = 4
# 2348 Error: gdd_length = 4
# 2349 Error: 503, Retrying...
# 2349 Error: gdd_length = 4
# 2350 Error: gdd_length = 4
# 2351 Error: gdd_length = 4
# 2352 Error: gdd_length = 4
# 2353 Success
# 2354 Error: gdd_length = 4
# 2355 Error: gdd_length = 4
# 2356 Error: gdd_length = 4
# 2357 Error: gdd_length = 4
# 2358 Error: gdd_length = 4
# 2359 Error: gdd_length = 4
# 2360 Success
# 2361 Error: gdd_length = 4
# 2362 Error: gdd_length = 4
# 2363 Error: gdd_length = 4
# 2364 Error: gdd_length = 4
# 2365 Error: gdd_length = 4
# 2366 Error: gdd_length = 4
# 2367 Error: gdd_length = 4
# 2368 Error: gdd_length = 4
# 2369 Success
# 2370 Success
# 2371 Success
# 2372 Success
# 2373 Error: gdd_length = 4
# 2374 Error: gdd_length = 4
# 2375 Error: gdd_length = 4
# 2376 Success
# 2377 Success
# 2378 Error: gdd_length = 4
# 2379 Error: gdd_length = 4
# 2380 Error: gdd_length = 4
# 2381 Error: gdd_length = 4
# 2382 Error: gdd_length = 4
# 2383 Error: gdd_length = 4
# 2384 Error: gdd_length = 4
# 2385 Error: gdd_length = 4
# 2386 Success
# 2387 Success
# 2388 Error: gdd_length = 4
# 2389 Success
# 2390 Error: gdd_length = 4
# 2391 Error: gdd_length = 4
# 2392 Error: gdd_length = 4
# 2393 Error: gdd_length = 4
# 2394 Success
# 2395 Error: gdd_length = 4
# 2396 Error: gdd_length = 4
# 2397 Error: gdd_length = 4
# 2398 Error: gdd_length = 4
# 2399 Success
# 2400 Success
# 2401 Error: gdd_length = 4
# 2402 Error: gdd_length = 4
# 2403 Success
# 2404 Success
# 2405 Success
# 2406 Success
# 2407 Success
# 2408 Error: gdd_length = 4
# 2409 Error: gdd_length = 4
# 2410 Error: gdd_length = 4
# 2411 Success
# 2412 Success
# 2413 Error: gdd_length = 4
# 2414 Success
# 2415 Error: gdd_length = 4
# 2416 Error: gdd_length = 4
# 2417 Error: gdd_length = 4
# 2418 Error: gdd_length = 4
# 2419 Error: 503, Retrying...
# 2419 Error: gdd_length = 4
# 2420 Success
# 2421 Success
# 2422 Error: gdd_length = 4
# 2423 Error: gdd_length = 4
# 2424 Error: gdd_length = 4
# 2425 Success
# 2426 Success
# 2427 Success
# 2428 Error: gdd_length = 4
# 2429 Error: gdd_length = 4
# 2430 Error: gdd_length = 4
# 2431 Error: gdd_length = 4
# 2432 Error: gdd_length = 4
# 2433 Error: gdd_length = 4
# 2434 Success
# 2435 Error: gdd_length = 4
# 2436 Error: gdd_length = 4
# 2437 Success
# 2438 Error: gdd_length = 4
# 2439 Error: gdd_length = 4
# 2440 Success
# 2441 Error: gdd_length = 4
# 2442 Success
# 2443 Success
# 2444 Error: gdd_length = 4
# 2445 Error: gdd_length = 4
# 2446 Error: gdd_length = 4
# 2447 Error: gdd_length = 4
# 2448 Success
# 2449 Success
# 2450 Error: gdd_length = 4
# 2451 Error: gdd_length = 4
# 2452 Success
# 2453 Error: gdd_length = 4
# 2454 Success
# 2455 Error: gdd_length = 4
# 2456 Error: gdd_length = 4
# 2457 Error: gdd_length = 4
# 2458 Error: gdd_length = 4
# 2459 Success
# 2460 Error: gdd_length = 4
# 2461 Error: gdd_length = 4
# 2462 Error: gdd_length = 4
# 2463 Success
# 2464 Success
# 2465 Error: gdd_length = 4
# 2466 Error: gdd_length = 4
# 2467 Success
# 2468 Error: gdd_length = 4
# 2469 Error: gdd_length = 4
# 2470 Error: gdd_length = 4
# 2471 Error: gdd_length = 4
# 2472 Error: 503, Retrying...
# 2472 Success
# 2473 Error: gdd_length = 4
# 2474 Success
# 2475 Success
# 2476 Error: 503, Retrying...
# 2476 Error: gdd_length = 4
# 2477 Error: gdd_length = 4
# 2478 Error: gdd_length = 4
# 2479 Error: gdd_length = 4
# 2480 Error: gdd_length = 4
# 2481 Success
# 2482 Success
# 2483 Error: 503, Retrying...
# 2483 Error: gdd_length = 4
# 2484 Error: gdd_length = 4
# 2485 Success
# 2486 Error: gdd_length = 4
# 2487 Success
# 2488 Error: gdd_length = 4
# 2489 Error: gdd_length = 4
# 2490 Success
# 2491 Success
# 2492 Error: gdd_length = 4
# 2493 Success
# 2494 Success
# 2495 Error: gdd_length = 4
# 2496 Error: gdd_length = 4
# 2497 Success
# 2498 Error: gdd_length = 4
# 2499 Error: gdd_length = 4
# 2500 Error: gdd_length = 4
# 2501 Error: gdd_length = 4
# 2502 Error: gdd_length = 4
# 2503 Error: gdd_length = 4
# 2504 Success
# 2505 Success
# 2506 Success
# 2507 Error: gdd_length = 4
# 2508 Success
# 2509 Error: gdd_length = 4
# 2510 Error: gdd_length = 4
# 2511 Error: gdd_length = 4
# 2512 Error: gdd_length = 4
# 2513 Error: gdd_length = 4
# 2514 Success
# 2515 Error: gdd_length = 4
# 2516 Success
# 2517 Success
# 2518 Error: 503, Retrying...
# 2518 Error: gdd_length = 4
# 2519 Success
# 2520 Success
# 2521 Success
# 2522 Error: gdd_length = 4
# 2523 Error: gdd_length = 4
# 2524 Error: gdd_length = 4
# 2525 Error: gdd_length = 4
# 2526 Error: gdd_length = 4
# 2527 Error: gdd_length = 4
# 2528 Error: gdd_length = 4
# 2529 Error: gdd_length = 4
# 2530 Error: gdd_length = 4
# 2531 Error: gdd_length = 4
# 2532 Success
# 2533 Error: gdd_length = 4
# 2534 Error: gdd_length = 4
# 2535 Success
# 2536 Error: gdd_length = 4
# 2537 Error: gdd_length = 4
# 2538 Error: gdd_length = 4
# 2539 Success
# 2540 Success
# 2541 Success
# 2542 Error: gdd_length = 4
# 2543 Success
# 2544 Error: gdd_length = 4
# 2545 Error: gdd_length = 4
# 2546 Success
# 2547 Error: gdd_length = 4
# 2548 Error: gdd_length = 4
# 2549 Success
# 2550 Success
# 2551 Error: gdd_length = 4
# 2552 Error: gdd_length = 4
# 2553 Success
# 2554 Success
# 2555 Success
# 2556 Error: gdd_length = 4
# 2557 Error: gdd_length = 4
# 2558 Error: gdd_length = 4
# 2559 Success
# 2560 Success
# 2561 Success
# 2562 Success
# 2563 Success
# 2564 Error: gdd_length = 4
# 2565 Error: 503, Retrying...
# 2565 Error: gdd_length = 4
# 2566 Error: gdd_length = 4
# 2567 Error: gdd_length = 4
# 2568 Success
# 2569 Error: gdd_length = 4
# 2570 Success
# 2571 Success
# 2572 Error: gdd_length = 4
# 2573 Error: gdd_length = 4
# 2574 Error: gdd_length = 4
# 2575 Error: gdd_length = 4
# 2576 Error: gdd_length = 4
# 2577 Success
# 2578 Error: gdd_length = 4
# 2579 Success
# 2580 Success
# 2581 Error: gdd_length = 4
# 2582 Error: gdd_length = 4
# 2583 Error: gdd_length = 4
# 2584 Error: gdd_length = 4
# 2585 Success
# 2586 Error: gdd_length = 4
# 2587 Error: gdd_length = 4
# 2588 Success
# 2589 Error: gdd_length = 4
# 2590 Error: gdd_length = 4
# 2591 Success
# 2592 Error: gdd_length = 4
# 2593 Success
# 2594 Error: gdd_length = 4
# 2595 Success
# 2596 Error: gdd_length = 4
# 2597 Success
# 2598 Success
# 2599 Error: gdd_length = 4
# 2600 Success
# 2601 Success
# 2602 Error: gdd_length = 4
# 2603 Error: gdd_length = 4
# 2604 Error: gdd_length = 4
# 2605 Success
# 2606 Success
# 2607 Error: gdd_length = 4
# 2608 Error: gdd_length = 4
# 2609 Success
# 2610 Success
# 2611 Error: gdd_length = 4
# 2612 Error: gdd_length = 4
# 2613 Error: gdd_length = 4
# 2614 Error: gdd_length = 4
# 2615 Error: gdd_length = 4
# 2616 Error: gdd_length = 4
# 2617 Success
# 2618 Error: gdd_length = 4
# 2619 Success
# 2620 Success
# 2621 Success
# 2622 Error: gdd_length = 4
# 2623 Error: gdd_length = 4
# 2624 Error: gdd_length = 4
# 2625 Success
# 2626 Success
# 2627 Success
# 2628 Error: gdd_length = 4
# 2629 Error: gdd_length = 4
# 2630 Error: gdd_length = 4
# 2631 Error: gdd_length = 4
# 2632 Error: gdd_length = 4
# 2633 Error: gdd_length = 4
# 2634 Error: gdd_length = 4
# 2635 Error: gdd_length = 4
# 2636 Error: gdd_length = 4
# 2637 Error: gdd_length = 4
# 2638 Error: gdd_length = 4
# 2639 Error: gdd_length = 4
# 2640 Error: gdd_length = 4
# 2641 Error: gdd_length = 4
# 2642 Error: gdd_length = 4
# 2643 Error: gdd_length = 4
# 2644 Error: gdd_length = 4
# 2645 Error: gdd_length = 4
# 2646 Error: gdd_length = 4
# 2647 Error: gdd_length = 4
# 2648 Error: gdd_length = 4
# 2649 Error: gdd_length = 4
# 2650 Error: gdd_length = 4
# 2651 Error: gdd_length = 4
# 2652 Error: gdd_length = 4
# 2653 Error: gdd_length = 4
# 2654 Error: gdd_length = 4
# 2655 Error: gdd_length = 4
# 2656 Error: 503, Retrying...
# 2656 Error: gdd_length = 4
# 2657 Error: gdd_length = 4
# 2658 Error: gdd_length = 4
# 2659 Success
# 2660 Success
# 2661 Success
# 2662 Success
# 2663 Success
# 2664 Success
# 2665 Success
# 2666 Success
# 2667 Success
# 2668 Error: gdd_length = 4
# 2669 Error: gdd_length = 4
# 2670 Error: gdd_length = 4
# 2671 Success
# 2672 Success
# 2673 Error: gdd_length = 4
# 2674 Error: gdd_length = 4
# 2675 Success
# 2676 Success
# 2677 Error: gdd_length = 4
# 2678 Success
# 2679 Success
# 2680 Success
# 2681 Success
# 2682 Error: gdd_length = 4
# 2683 Success

# %%
gdd.columns = ['ID', 'Latitude', 'Longitude', 'Name', 
               'January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']

# %%
# Create a geometry column using the longitude and latitude
geometry = [Point(xy) for xy in zip(gdd['Longitude'], gdd['Latitude'])]

# Convert to GeoDataFrame
gdd_gdf = gpd.GeoDataFrame(gdd, geometry=geometry)

# Set the Coordinate Reference System (CRS) to WGS84 (EPSG:4326)
gdd_gdf.set_crs(epsg=4326, inplace=True)
# Out:
#                     ID   Latitude  Longitude  \
# 0    GHCND:USC00210018  47.299100 -96.516100
# 1    GHCND:USC00210050  48.300500 -95.981600
# 2    GHCND:USC00210059  46.525700 -93.667400
# 3    GHCND:USC00210075  43.606400 -93.301900
# 4    GHCND:USC00210157  43.883500 -94.166500
# ..                 ...        ...        ...
# 188  GHCND:USW00094960  45.062220 -93.351070
# 189  GHCND:USW00094961  48.726060 -94.612160
# 190  GHCND:USW00094963  44.832140 -93.470510
# 191  GHCND:USW00094967  46.899670 -95.066820
# 192  GHCND:USW00094992  47.745404 -90.345639
#
#                                         Name  January  February   March  \
# 0                                 ADA, MN US      0.0   -7777.0     1.0
# 1                      AGASSIZ REFUGE, MN US      0.0   -7777.0     1.0
# 2                          AITKIN 2 E, MN US      0.0       0.0 -7777.0
# 3                     ALBERT LEA 3 SE, MN US      0.0   -7777.0     6.0
# 4                               AMBOY, MN US      0.0   -7777.0     9.0
# ..                                       ...      ...       ...     ...
# 188       MINNEAPOLIS CRYSTAL AIRPORT, MN US      0.0   -7777.0     7.0
# 189    BAUDETTE INTERNATIONAL AIRPORT, MN US      0.0   -7777.0 -7777.0
# 190  MINNEAPOLIS FLYING CLOUD AIRPORT, MN US      0.0   -7777.0     7.0
# 191     PARK RAPIDS MUNICIPAL AIRPORT, MN US      0.0   -7777.0     1.0
# 192                      GRAND MARAIS, MN US      0.0       0.0     0.0
#
#      April    May   June   July  August  September  October  November  \
# 0     51.0  227.0  460.0  614.0   570.0      269.0     49.0       2.0
# 1     47.0  238.0  460.0  615.0   555.0      266.0     50.0       1.0
# 2     30.0  159.0  385.0  544.0   471.0      219.0     47.0       3.0
# 3     70.0  272.0  539.0  680.0   604.0      341.0     90.0       9.0
# 4     90.0  328.0  594.0  714.0   629.0      381.0    125.0      12.0
# ..     ...    ...    ...    ...     ...        ...      ...       ...
# 188   75.0  280.0  544.0  704.0   660.0      349.0     97.0       7.0
# 189   23.0  146.0  357.0  507.0   443.0      181.0     28.0       1.0
# 190   81.0  302.0  568.0  727.0   649.0      365.0    103.0      10.0
# 191   32.0  173.0  381.0  545.0   487.0      218.0     37.0       1.0
# 192    2.0   21.0   98.0  286.0   343.0      164.0     20.0   -7777.0
#
#      December                    geometry
# 0     -7777.0  POINT (-96.51610 47.29910)
# 1         0.0  POINT (-95.98160 48.30050)
# 2         0.0  POINT (-93.66740 46.52570)
# 3     -7777.0  POINT (-93.30190 43.60640)
# 4     -7777.0  POINT (-94.16650 43.88350)
# ..        ...                         ...
# 188   -7777.0  POINT (-93.35107 45.06222)
# 189       0.0  POINT (-94.61216 48.72606)
# 190   -7777.0  POINT (-93.47051 44.83214)
# 191       0.0  POINT (-95.06682 46.89967)
# 192       0.0  POINT (-90.34564 47.74540)
#
# [193 rows x 17 columns]

# %%
gdd_gdf.to_csv(gdd_csv_path, index=False)

# %%
#gdd = pd.read_csv(gdd_csv_path)
#gdd['geometry'] = [Point(xy) for xy in zip(gdd['Longitude'], gdd['Latitude'])]
#gdd_gdf = gpd.GeoDataFrame(gdd, geometry = 'geometry', crs = 'EPSG:4326')

# %%
min_latitude = 43
max_latitude = 49.5
min_longitude = -97.5
max_longitude = -89

invalid_geom = gdd_gdf[(gdd_gdf['Latitude'] < min_latitude) |
                       (gdd_gdf['Latitude'] > max_latitude) |
                       (gdd_gdf['Longitude'] < min_longitude) |
                       (gdd_gdf['Longitude'] > max_longitude)]

if invalid_geom.empty:
    print('All geometry is valid')
else:
    print('Invalid points:')
    print(invalid_geom)
    gdd_gdf = gdd_gdf[(gdd_gdf['Latitude'] >= min_latitude) &
                      (gdd_gdf['Latitude'] <= max_latitude) &
                      (gdd_gdf['Longitude'] >= min_longitude) &
                      (gdd_gdf['Longitude'] <= max_longitude)]
# Out:
# All geometry is valid

# %%
warm_months = ['May', 'June', 'July', 'August', 'September']
cold_months = ['December', 'January', 'February', 'March']

invalid_gdd = gdd_gdf.apply(lambda row: any(row[winter] >= row[summer] for winter in cold_months for summer in warm_months), axis = 1)

gdd_gdf = gdd_gdf[~invalid_gdd]

# %%
gdd_gdf.replace(-7777, 0, inplace=True)

# %%
#connect to the new database to enable PostGIS
connection_string = f'postgresql://<user>:<password>@34.133.43.30:5432/lab2'
engine = create_engine(connection_string)

# Push the GeoDataFrame to PostGIS
table_name = "mn_gdd"
gdd_gdf.to_postgis(table_name, engine, if_exists="replace", index=False)

print(f"GeoDataFrame successfully pushed to the PostGIS table '{table_name}'.")
# Out:
# GeoDataFrame successfully pushed to the PostGIS table 'mn_gdd'.
