# %%
import requests
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import time
from sqlalchemy import create_engine, text
import psycopg2

# %%
temp_csv_path = r'C:\Users\tjjoh\OneDrive\Desktop\GIS 5572\Lab2\temperature.csv'

# %%
url = r'https://www.ncei.noaa.gov/cdo-web/api/v2/stations'
params = {
    'locationid': 'FIPS:27', #Minnesota is 27
    'datasetid': 'GHCND', #Global Historical Climatology Network Daily
    'limit': 1000 #Maximum results per request
}
headers = {'token': 'JgSvDOViKdKyBepyxxCKfJDaMaQghdfB'} #API token

stations = []

# %%
#Get a list of all stations in Minnesota
offset = 0 #Pagination will be necessary to retrieve all the data

while url:
    params['offset'] = offset #set the offset parameter
    try:
        response = requests.get(url, params = params, headers = headers) #make API request
        data = response.json() #transform to json
        
        if 'results' in data:
            stations.extend(data['results'])
            #for i in range(len(data['results'])):
                #stations.extend([data['results'][i]['id']]) #if results exist, add the station ids to the the list
                
            if len(data['results']) < params['limit']: #check if all data has been retrieved
                break
        else:
            break

        offset = offset + params['limit'] #update offset
        
    except:
        print(f'Error retriving data: {response.status_code}')
        break

# %%
url = r'https://www.ncei.noaa.gov/cdo-web/api/v2/data'
params = {
    'datasetid': 'NORMAL_MLY',
    'startdate': '2010-01-01',
    'enddate': '2010-12-01',
    'units': 'standard',
    'limit': 1000
}

# %%
temperature = pd.DataFrame() #create empty dataframe

for i in range(2189, len(stations)): #the first 2188 give errors
    attempt = 1 #create a counter for how many time to attempt to retrieve data
    max_attempts = 5 #maximum number of attempts
    success = False #default state of whether api request was successful

    while attempt <= max_attempts and not success: #iterate up to 3 times to try and make a successful api call
        try:
            params['stationid'] = stations[i]['id'] #add station id to url parameters
            response = requests.get(url, params = params, headers = headers) #retrieve data
            data = response.json() #convert to json
        
            temp = [stations[i]['id'], stations[i]['latitude'], stations[i]['longitude'], stations[i]['name']] #extract station id, location, and name
            for j in range(len(data['results'])): #iterate through retrieved data
                if data['results'][j]['datatype'] == 'MLY-TAVG-NORMAL': #find desired dataset
                    temp.extend([data['results'][j]['value']]) #add data to station info list

            if len(temp) == 16: #check to see if temp is the proper length
                temperature = pd.concat([temperature, pd.DataFrame([temp])], ignore_index = True) #add to temperature dataframe if the proper data exists
                print(f'{i} Success')
            else:
                print(f'{i} Error: temp_length = {len(temp)}')

            success = True #api call was succesful

        except:
            if response.status_code == 503: #check if api call was unsuccesful
                attempt += 1
                if attempt <= max_attempts: #if attempts remain, try api request again
                    print(f'{i} Error: 503, Retrying...')
                else: #if no attempts remain, skip point
                    print(f'{i} Error: 503, Failed to retrieve data.')
            elif response.status_code != 200: #check if status is not OK
                print(f'{i} Error: {response.status_code}')
                success = True
            elif len(temp) != 16: #check if temp is the proper length
                print(f'{i} Error: temp_length = {len(temp)}')
                success = True
            else:
                print(f'{i} Error: unknown')
                success = True

        time.sleep(0.5)
# Out:
# 2189 Success
# 2190 Success
# 2191 Success
# 2192 Success
# 2193 Error: temp_length = 4
# 2194 Error: temp_length = 4
# 2195 Error: temp_length = 4
# 2196 Error: temp_length = 4
# 2197 Error: temp_length = 4
# 2198 Error: temp_length = 4
# 2199 Error: temp_length = 4
# 2200 Success
# 2201 Success
# 2202 Error: temp_length = 4
# 2203 Success
# 2204 Success
# 2205 Error: temp_length = 4
# 2206 Success
# 2207 Success
# 2208 Error: temp_length = 4
# 2209 Success
# 2210 Error: temp_length = 4
# 2211 Error: temp_length = 4
# 2212 Error: temp_length = 4
# 2213 Error: temp_length = 4
# 2214 Success
# 2215 Error: temp_length = 4
# 2216 Success
# 2217 Success
# 2218 Success
# 2219 Error: temp_length = 4
# 2220 Error: temp_length = 4
# 2221 Error: temp_length = 4
# 2222 Error: temp_length = 4
# 2223 Error: temp_length = 4
# 2224 Success
# 2225 Error: temp_length = 4
# 2226 Error: temp_length = 4
# 2227 Error: temp_length = 4
# 2228 Error: temp_length = 4
# 2229 Error: temp_length = 4
# 2230 Error: temp_length = 4
# 2231 Success
# 2232 Error: 503, Retrying...
# 2232 Success
# 2233 Error: temp_length = 4
# 2234 Error: temp_length = 4
# 2235 Success
# 2236 Success
# 2237 Success
# 2238 Success
# 2239 Success
# 2240 Success
# 2241 Success
# 2242 Success
# 2243 Success
# 2244 Success
# 2245 Success
# 2246 Error: temp_length = 4
# 2247 Error: temp_length = 4
# 2248 Error: temp_length = 4
# 2249 Error: temp_length = 4
# 2250 Success
# 2251 Success
# 2252 Error: temp_length = 4
# 2253 Error: temp_length = 4
# 2254 Error: temp_length = 4
# 2255 Success
# 2256 Success
# 2257 Success
# 2258 Error: temp_length = 4
# 2259 Error: temp_length = 4
# 2260 Error: temp_length = 4
# 2261 Error: temp_length = 4
# 2262 Success
# 2263 Error: temp_length = 4
# 2264 Error: temp_length = 4
# 2265 Success
# 2266 Error: temp_length = 4
# 2267 Success
# 2268 Error: temp_length = 4
# 2269 Success
# 2270 Error: temp_length = 4
# 2271 Error: temp_length = 4
# 2272 Success
# 2273 Error: temp_length = 4
# 2274 Error: temp_length = 4
# 2275 Error: temp_length = 4
# 2276 Success
# 2277 Error: temp_length = 4
# 2278 Error: temp_length = 4
# 2279 Error: temp_length = 4
# 2280 Success
# 2281 Success
# 2282 Error: temp_length = 4
# 2283 Success
# 2284 Success
# 2285 Error: temp_length = 4
# 2286 Success
# 2287 Error: temp_length = 4
# 2288 Error: temp_length = 4
# 2289 Error: temp_length = 4
# 2290 Error: temp_length = 4
# 2291 Success
# 2292 Error: temp_length = 4
# 2293 Error: temp_length = 4
# 2294 Error: temp_length = 4
# 2295 Error: temp_length = 4
# 2296 Error: temp_length = 4
# 2297 Success
# 2298 Success
# 2299 Success
# 2300 Error: temp_length = 4
# 2301 Error: temp_length = 4
# 2302 Success
# 2303 Success
# 2304 Success
# 2305 Error: 503, Retrying...
# 2305 Error: temp_length = 4
# 2306 Success
# 2307 Success
# 2308 Error: temp_length = 4
# 2309 Error: temp_length = 4
# 2310 Success
# 2311 Error: temp_length = 4
# 2312 Success
# 2313 Success
# 2314 Error: temp_length = 4
# 2315 Error: temp_length = 4
# 2316 Error: temp_length = 4
# 2317 Success
# 2318 Error: temp_length = 4
# 2319 Error: temp_length = 4
# 2320 Error: temp_length = 4
# 2321 Success
# 2322 Success
# 2323 Error: temp_length = 4
# 2324 Error: temp_length = 4
# 2325 Success
# 2326 Error: temp_length = 4
# 2327 Error: temp_length = 4
# 2328 Error: temp_length = 4
# 2329 Success
# 2330 Success
# 2331 Success
# 2332 Error: temp_length = 4
# 2333 Success
# 2334 Error: temp_length = 4
# 2335 Success
# 2336 Error: temp_length = 4
# 2337 Success
# 2338 Success
# 2339 Error: temp_length = 4
# 2340 Error: 503, Retrying...
# 2340 Error: 503, Retrying...
# 2340 Error: 503, Retrying...
# 2340 Success
# 2341 Error: temp_length = 4
# 2342 Error: temp_length = 4
# 2343 Error: temp_length = 4
# 2344 Success
# 2345 Error: temp_length = 4
# 2346 Error: temp_length = 4
# 2347 Error: temp_length = 4
# 2348 Error: temp_length = 4
# 2349 Error: temp_length = 4
# 2350 Error: temp_length = 4
# 2351 Error: temp_length = 4
# 2352 Error: temp_length = 4
# 2353 Success
# 2354 Error: temp_length = 4
# 2355 Error: temp_length = 4
# 2356 Error: temp_length = 4
# 2357 Error: temp_length = 4
# 2358 Error: temp_length = 4
# 2359 Error: temp_length = 4
# 2360 Success
# 2361 Error: temp_length = 4
# 2362 Error: temp_length = 4
# 2363 Error: temp_length = 4
# 2364 Error: temp_length = 4
# 2365 Error: temp_length = 4
# 2366 Error: temp_length = 4
# 2367 Error: temp_length = 4
# 2368 Error: temp_length = 4
# 2369 Success
# 2370 Success
# 2371 Success
# 2372 Error: 503, Retrying...
# 2372 Error: 503, Retrying...
# 2372 Success
# 2373 Error: temp_length = 4
# 2374 Error: temp_length = 4
# 2375 Error: temp_length = 4
# 2376 Error: 503, Retrying...
# 2376 Success
# 2377 Success
# 2378 Error: temp_length = 4
# 2379 Error: temp_length = 4
# 2380 Error: temp_length = 4
# 2381 Error: temp_length = 4
# 2382 Error: temp_length = 4
# 2383 Error: temp_length = 4
# 2384 Error: temp_length = 4
# 2385 Error: temp_length = 4
# 2386 Success
# 2387 Success
# 2388 Error: temp_length = 4
# 2389 Success
# 2390 Error: temp_length = 4
# 2391 Error: temp_length = 4
# 2392 Error: temp_length = 4
# 2393 Error: temp_length = 4
# 2394 Success
# 2395 Error: temp_length = 4
# 2396 Error: temp_length = 4
# 2397 Error: temp_length = 4
# 2398 Error: temp_length = 4
# 2399 Success
# 2400 Success
# 2401 Error: temp_length = 4
# 2402 Error: temp_length = 4
# 2403 Success
# 2404 Success
# 2405 Success
# 2406 Success
# 2407 Success
# 2408 Error: temp_length = 4
# 2409 Error: temp_length = 4
# 2410 Error: temp_length = 4
# 2411 Success
# 2412 Success
# 2413 Error: temp_length = 4
# 2414 Success
# 2415 Error: temp_length = 4
# 2416 Error: temp_length = 4
# 2417 Error: temp_length = 4
# 2418 Error: temp_length = 4
# 2419 Error: temp_length = 4
# 2420 Success
# 2421 Success
# 2422 Error: temp_length = 4
# 2423 Error: temp_length = 4
# 2424 Error: temp_length = 4
# 2425 Success
# 2426 Success
# 2427 Success
# 2428 Error: temp_length = 4
# 2429 Error: temp_length = 4
# 2430 Error: temp_length = 4
# 2431 Error: temp_length = 4
# 2432 Error: temp_length = 4
# 2433 Error: temp_length = 4
# 2434 Success
# 2435 Error: temp_length = 4
# 2436 Error: temp_length = 4
# 2437 Success
# 2438 Error: temp_length = 4
# 2439 Error: temp_length = 4
# 2440 Success
# 2441 Error: temp_length = 4
# 2442 Success
# 2443 Success
# 2444 Error: temp_length = 4
# 2445 Error: temp_length = 4
# 2446 Error: temp_length = 4
# 2447 Error: temp_length = 4
# 2448 Success
# 2449 Success
# 2450 Error: temp_length = 4
# 2451 Error: temp_length = 4
# 2452 Success
# 2453 Error: temp_length = 4
# 2454 Success
# 2455 Error: temp_length = 4
# 2456 Error: temp_length = 4
# 2457 Error: temp_length = 4
# 2458 Error: temp_length = 4
# 2459 Success
# 2460 Error: temp_length = 4
# 2461 Error: temp_length = 4
# 2462 Error: temp_length = 4
# 2463 Success
# 2464 Success
# 2465 Error: temp_length = 4
# 2466 Error: temp_length = 4
# 2467 Success
# 2468 Error: temp_length = 4
# 2469 Error: temp_length = 4
# 2470 Error: temp_length = 4
# 2471 Error: temp_length = 4
# 2472 Success
# 2473 Error: temp_length = 4
# 2474 Success
# 2475 Success
# 2476 Error: temp_length = 4
# 2477 Error: temp_length = 4
# 2478 Error: temp_length = 4
# 2479 Error: temp_length = 4
# 2480 Error: temp_length = 4
# 2481 Success
# 2482 Success
# 2483 Error: temp_length = 4
# 2484 Error: temp_length = 4
# 2485 Success
# 2486 Error: temp_length = 4
# 2487 Success
# 2488 Error: temp_length = 4
# 2489 Error: temp_length = 4
# 2490 Success
# 2491 Success
# 2492 Error: temp_length = 4
# 2493 Success
# 2494 Success
# 2495 Error: temp_length = 4
# 2496 Error: temp_length = 4
# 2497 Success
# 2498 Error: temp_length = 4
# 2499 Error: temp_length = 4
# 2500 Error: temp_length = 4
# 2501 Error: temp_length = 4
# 2502 Error: temp_length = 4
# 2503 Error: 503, Retrying...
# 2503 Error: temp_length = 4
# 2504 Success
# 2505 Success
# 2506 Error: 503, Retrying...
# 2506 Success
# 2507 Error: temp_length = 4
# 2508 Success
# 2509 Error: temp_length = 4
# 2510 Error: temp_length = 4
# 2511 Error: temp_length = 4
# 2512 Error: temp_length = 4
# 2513 Error: temp_length = 4
# 2514 Success
# 2515 Error: temp_length = 4
# 2516 Success
# 2517 Success
# 2518 Error: temp_length = 4
# 2519 Success
# 2520 Success
# 2521 Success
# 2522 Error: temp_length = 4
# 2523 Error: temp_length = 4
# 2524 Error: temp_length = 4
# 2525 Error: temp_length = 4
# 2526 Error: temp_length = 4
# 2527 Error: temp_length = 4
# 2528 Error: temp_length = 4
# 2529 Error: temp_length = 4
# 2530 Error: temp_length = 4
# 2531 Error: temp_length = 4
# 2532 Success
# 2533 Error: temp_length = 4
# 2534 Error: temp_length = 4
# 2535 Success
# 2536 Error: 503, Retrying...
# 2536 Error: temp_length = 4
# 2537 Error: temp_length = 4
# 2538 Error: temp_length = 4
# 2539 Success
# 2540 Success
# 2541 Success
# 2542 Error: temp_length = 4
# 2543 Success
# 2544 Error: temp_length = 4
# 2545 Error: temp_length = 4
# 2546 Success
# 2547 Error: temp_length = 4
# 2548 Error: temp_length = 4
# 2549 Success
# 2550 Success
# 2551 Error: temp_length = 4
# 2552 Error: temp_length = 4
# 2553 Success
# 2554 Success
# 2555 Success
# 2556 Error: temp_length = 4
# 2557 Error: temp_length = 4
# 2558 Error: temp_length = 4
# 2559 Success
# 2560 Success
# 2561 Success
# 2562 Success
# 2563 Success
# 2564 Error: temp_length = 4
# 2565 Error: temp_length = 4
# 2566 Error: temp_length = 4
# 2567 Error: temp_length = 4
# 2568 Success
# 2569 Error: temp_length = 4
# 2570 Success
# 2571 Success
# 2572 Error: temp_length = 4
# 2573 Error: temp_length = 4
# 2574 Error: temp_length = 4
# 2575 Error: temp_length = 4
# 2576 Error: temp_length = 4
# 2577 Success
# 2578 Error: temp_length = 4
# 2579 Success
# 2580 Success
# 2581 Error: temp_length = 4
# 2582 Error: temp_length = 4
# 2583 Error: temp_length = 4
# 2584 Error: temp_length = 4
# 2585 Success
# 2586 Error: temp_length = 4
# 2587 Error: temp_length = 4
# 2588 Success
# 2589 Error: temp_length = 4
# 2590 Error: temp_length = 4
# 2591 Success
# 2592 Error: temp_length = 4
# 2593 Success
# 2594 Error: temp_length = 4
# 2595 Success
# 2596 Error: temp_length = 4
# 2597 Success
# 2598 Success
# 2599 Error: temp_length = 4
# 2600 Success
# 2601 Success
# 2602 Error: temp_length = 4
# 2603 Error: temp_length = 4
# 2604 Error: temp_length = 4
# 2605 Success
# 2606 Success
# 2607 Error: temp_length = 4
# 2608 Error: temp_length = 4
# 2609 Success
# 2610 Success
# 2611 Error: temp_length = 4
# 2612 Error: temp_length = 4
# 2613 Error: temp_length = 4
# 2614 Error: temp_length = 4
# 2615 Error: temp_length = 4
# 2616 Error: temp_length = 4
# 2617 Success
# 2618 Error: temp_length = 4
# 2619 Success
# 2620 Success
# 2621 Success
# 2622 Error: temp_length = 4
# 2623 Error: temp_length = 4
# 2624 Error: temp_length = 4
# 2625 Success
# 2626 Success
# 2627 Error: 503, Retrying...
# 2627 Success
# 2628 Error: temp_length = 4
# 2629 Error: temp_length = 4
# 2630 Error: temp_length = 4
# 2631 Error: temp_length = 4
# 2632 Error: temp_length = 4
# 2633 Error: temp_length = 4
# 2634 Error: temp_length = 4
# 2635 Error: temp_length = 4
# 2636 Error: temp_length = 4
# 2637 Error: temp_length = 4
# 2638 Error: temp_length = 4
# 2639 Error: temp_length = 4
# 2640 Error: temp_length = 4
# 2641 Error: temp_length = 4
# 2642 Error: temp_length = 4
# 2643 Error: temp_length = 4
# 2644 Error: temp_length = 4
# 2645 Error: temp_length = 4
# 2646 Error: temp_length = 4
# 2647 Error: temp_length = 4
# 2648 Error: temp_length = 4
# 2649 Error: temp_length = 4
# 2650 Error: temp_length = 4
# 2651 Error: temp_length = 4
# 2652 Error: temp_length = 4
# 2653 Error: temp_length = 4
# 2654 Error: temp_length = 4
# 2655 Error: temp_length = 4
# 2656 Error: temp_length = 4
# 2657 Error: temp_length = 4
# 2658 Error: temp_length = 4
# 2659 Success
# 2660 Success
# 2661 Success
# 2662 Success
# 2663 Success
# 2664 Success
# 2665 Success
# 2666 Success
# 2667 Success
# 2668 Error: temp_length = 4
# 2669 Error: temp_length = 4
# 2670 Error: temp_length = 4
# 2671 Success
# 2672 Success
# 2673 Error: temp_length = 4
# 2674 Error: temp_length = 4
# 2675 Success
# 2676 Success
# 2677 Error: temp_length = 4
# 2678 Success
# 2679 Success
# 2680 Success
# 2681 Success
# 2682 Error: temp_length = 4
# 2683 Success

# %%
temperature.columns = ['ID', 'Latitude', 'Longitude', 'Name', 
                       'January', 'February', 'March', 'April', 'May', 'June', 
                       'July', 'August', 'September', 'October', 'November', 'December']

# %%
# Create a geometry column using the longitude and latitude
geometry = [Point(xy) for xy in zip(temperature['Longitude'], temperature['Latitude'])]

# Convert to GeoDataFrame
temperature_gdf = gpd.GeoDataFrame(temperature, geometry=geometry)

# Set the Coordinate Reference System (CRS) to WGS84 (EPSG:4326)
temperature_gdf.set_crs(epsg=4326, inplace=True)
# Out:
#                     ID   Latitude  Longitude  \
# 0    GHCND:USC00210018  47.299100 -96.516100
# 1    GHCND:USC00210050  48.300500 -95.981600
# 2    GHCND:USC00210059  46.525700 -93.667400
# 3    GHCND:USC00210075  43.606400 -93.301900
# 4    GHCND:USC00210157  43.883500 -94.166500
# ..                 ...        ...        ...
# 188  GHCND:USW00094960  45.062220 -93.351070
# 189  GHCND:USW00094961  48.726060 -94.612160
# 190  GHCND:USW00094963  44.832140 -93.470510
# 191  GHCND:USW00094967  46.899670 -95.066820
# 192  GHCND:USW00094992  47.745404 -90.345639
#
#                                         Name  January  February  March  April  \
# 0                                 ADA, MN US      6.8      11.8   25.7   43.1
# 1                      AGASSIZ REFUGE, MN US      5.9      11.7   25.7   42.9
# 2                          AITKIN 2 E, MN US      9.9      14.7   26.8   41.8
# 3                     ALBERT LEA 3 SE, MN US     14.1      18.9   31.2   45.8
# 4                               AMBOY, MN US     15.7      20.8   33.1   47.5
# ..                                       ...      ...       ...    ...    ...
# 188       MINNEAPOLIS CRYSTAL AIRPORT, MN US     15.2      20.3   32.1   46.8
# 189    BAUDETTE INTERNATIONAL AIRPORT, MN US      5.4      10.7   23.7   40.2
# 190  MINNEAPOLIS FLYING CLOUD AIRPORT, MN US     15.4      20.3   32.2   47.2
# 191     PARK RAPIDS MUNICIPAL AIRPORT, MN US      6.8      12.4   25.7   41.2
# 192                      GRAND MARAIS, MN US     15.1      18.3   26.2   37.6
#
#       May  June  July  August  September  October  November  December  \
# 0    55.8  65.3  69.8    68.4       58.1     44.2      27.5      12.4
# 1    56.3  65.3  69.9    67.9       58.0     44.0      26.6      10.8
# 2    53.4  62.8  67.5    65.2       56.3     44.2      29.3      15.2
# 3    58.0  68.0  71.9    69.5       60.9     47.9      33.2      18.5
# 4    60.1  69.8  73.0    70.3       62.4     49.9      34.4      19.7
# ..    ...   ...   ...     ...        ...      ...       ...       ...
# 188  58.4  68.2  72.7    71.3       61.2     48.4      33.2      19.5
# 189  52.5  61.8  66.4    64.3       54.7     41.9      25.9      10.3
# 190  59.3  69.0  73.4    70.9       61.9     48.9      33.9      19.5
# 191  53.8  62.6  67.6    65.7       56.0     42.6      26.3      11.6
# 192  46.0  52.4  59.2    61.1       54.5     43.8      32.6      19.3
#
#                        geometry
# 0    POINT (-96.51610 47.29910)
# 1    POINT (-95.98160 48.30050)
# 2    POINT (-93.66740 46.52570)
# 3    POINT (-93.30190 43.60640)
# 4    POINT (-94.16650 43.88350)
# ..                          ...
# 188  POINT (-93.35107 45.06222)
# 189  POINT (-94.61216 48.72606)
# 190  POINT (-93.47051 44.83214)
# 191  POINT (-95.06682 46.89967)
# 192  POINT (-90.34564 47.74540)
#
# [193 rows x 17 columns]

# %%
temperature_gdf.to_csv(temp_csv_path, index=False)

# %%
#temperature = pd.read_csv(temp_csv_path)
#temperature['geometry'] = [Point(xy) for xy in zip(temperature['Longitude'], temperature['Latitude'])]
#temperature_gdf = gpd.GeoDataFrame(temperature, geometry = 'geometry', crs = 'EPSG:4326')

# %%
min_latitude = 43
max_latitude = 49.5
min_longitude = -97.5
max_longitude = -89

invalid_geom = temperature_gdf[(temperature_gdf['Latitude'] < min_latitude) |
                               (temperature_gdf['Latitude'] > max_latitude) |
                               (temperature_gdf['Longitude'] < min_longitude) |
                               (temperature_gdf['Longitude'] > max_longitude)]

if invalid_geom.empty:
    print('All geometry is valid')
else:
    print('Invalid points:')
    print(invalid_geom)
    temperature_gdf = temperature_gdf[(temperature_gdf['Latitude'] >= min_latitude) &
                                      (temperature_gdf['Latitude'] <= max_latitude) &
                                      (temperature_gdf['Longitude'] >= min_longitude) &
                                      (temperature_gdf['Longitude'] <= max_longitude)]
# Out:
# All geometry is valid

# %%
warm_months = ['May', 'June', 'July', 'August', 'September']
cold_months = ['December', 'January', 'February', 'March']

invalid_temps = temperature_gdf.apply(lambda row: any(row[winter] >= row[summer] for winter in cold_months for summer in warm_months), axis = 1)

temperature_gdf = temperature_gdf[~invalid_temps]

# %%
#Create a new database
#root database
db_string = 'postgresql+psycopg2://<user>:<password>@34.133.43.30:5432/postgres'

#create a SQLAlchemy engine
engine = create_engine(db_string, isolation_level = 'AUTOCOMMIT')

#name of new database
new_db_name = 'lab2'

#SQL query to create the database
create_db_query = text(f"CREATE DATABASE {new_db_name};")

try:
    with engine.connect() as connection:
        # Create the new database
        connection.execute(create_db_query)
        print(f"Database '{new_db_name}' created successfully.")
except:
    print(f"Database '{new_db_name}' already exists.")
# Out:
# Database 'lab2' already exists.

# %%
#connect to the new database to enable PostGIS
connection_string = f'postgresql://<user>:<password>@34.133.43.30:5432/{new_db_name}'
engine = create_engine(connection_string)

#SQL queries to enable PostGIS
#enable_postgis_query = text("""
#CREATE EXTENSION postgis;
#CREATE EXTENSION postgis_topology;
#""")  #adding PostGIS extensions

#with engine.connect() as new_connection:
#    #enable PostGIS
#    new_connection.execution_options(autocommit=True).execute(enable_postgis_query)
#    print(f"PostGIS enabled in database '{new_db_name}'.")

# Push the GeoDataFrame to PostGIS
table_name = "mn_temperature"
temperature_gdf.to_postgis(table_name, engine, if_exists="replace", index=False)

print(f"GeoDataFrame successfully pushed to the PostGIS table '{table_name}'.")
# Out:
# GeoDataFrame successfully pushed to the PostGIS table 'mn_temperature'.
